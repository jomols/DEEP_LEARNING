# %%
import cv2
import pytesseract
img=cv2.imread("vehicleplate.webp")
img
# Out:
# array([[[ 81,  81,  86],
#         [ 81,  81,  86],
#         [ 82,  83,  87],
#         ...,
#         [199, 221, 222],
#         [203, 226, 227],
#         [205, 227, 228]],
#
#        [[ 75,  76,  80],
#         [ 75,  76,  80],
#         [ 76,  77,  81],
#         ...,
#         [204, 224, 226],
#         [200, 220, 221],
#         [198, 218, 220]],
#
#        [[ 67,  67,  72],
#         [ 67,  67,  72],
#         [ 68,  69,  73],
#         ...,
#         [189, 206, 208],
#         [184, 202, 203],
#         [183, 201, 202]],
#
#        ...,
#
#        [[108, 118, 128],
#         [117, 128, 137],
#         [116, 126, 136],
#         ...,
#         [108, 122, 129],
#         [106, 119, 126],
#         [105, 118, 125]],
#
#        [[107, 117, 127],
#         [112, 123, 133],
#         [114, 124, 134],
#         ...,
#         [121, 135, 141],
#         [117, 131, 138],
#         [114, 128, 134]],
#
#        [[107, 117, 127],
#         [100, 110, 120],
#         [100, 110, 120],
#         ...,
#         [117, 131, 138],
#         [114, 128, 134],
#         [110, 124, 131]]], shape=(333, 500, 3), dtype=uint8)

# %%
cv2.imshow("frame",img)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
#set path into programmimg files
pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
data=pytesseract.image_to_string(img)
print(data)

# %%
dic=pytesseract.image_to_data(img,output_type=pytesseract.Output.DICT)
dic
# Out:
# {'level': [1, 2, 3, 4, 5],
#  'page_num': [1, 1, 1, 1, 1],
#  'block_num': [0, 1, 1, 1, 1],
#  'par_num': [0, 0, 1, 1, 1],
#  'line_num': [0, 0, 0, 1, 1],
#  'word_num': [0, 0, 0, 0, 1],
#  'left': [0, 0, 0, 0, 0],
#  'top': [0, 0, 0, 0, 0],
#  'width': [500, 0, 0, 0, 0],
#  'height': [333, 333, 333, 333, 333],
#  'conf': [-1, -1, -1, -1, 95],
#  'text': ['', '', '', '', '']}

# %%
n=len(dic['text'])
n
# Out:
# 5
