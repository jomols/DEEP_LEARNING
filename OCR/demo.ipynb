# %%
import cv2
import pytesseract

# %%
img=cv2.imread("ocr1.jpeg")
img
# Out:
# array([[[ 6,  5,  1],
#         [ 6,  5,  1],
#         [ 6,  5,  1],
#         ...,
#         [ 9,  4,  1],
#         [ 9,  4,  1],
#         [ 9,  4,  1]],
#
#        [[ 6,  5,  1],
#         [ 6,  5,  1],
#         [ 6,  5,  1],
#         ...,
#         [ 9,  4,  1],
#         [ 9,  4,  1],
#         [ 9,  4,  1]],
#
#        [[ 6,  5,  1],
#         [ 6,  5,  1],
#         [ 6,  5,  1],
#         ...,
#         [ 9,  4,  1],
#         [ 9,  4,  1],
#         [ 9,  4,  1]],
#
#        ...,
#
#        [[ 8,  3,  0],
#         [ 8,  3,  0],
#         [ 9,  4,  1],
#         ...,
#         [12,  7,  4],
#         [12,  7,  4],
#         [12,  7,  4]],
#
#        [[ 8,  3,  0],
#         [ 8,  3,  0],
#         [ 9,  4,  1],
#         ...,
#         [12,  7,  4],
#         [12,  7,  4],
#         [12,  7,  4]],
#
#        [[ 8,  3,  0],
#         [ 8,  3,  0],
#         [ 9,  4,  1],
#         ...,
#         [12,  7,  4],
#         [12,  7,  4],
# ...

# %%
cv2.imshow("frame",img)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
#set path into programmimg files
pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
#extract test from image
data=pytesseract.image_to_string(img)
print(data)
# Out:
# MoonShine

# %%
#properties
# dict
# space special character ;-1 to 10
# conf >=50 then it wil be a text #


dic=pytesseract.image_to_data(img,output_type=pytesseract.Output.DICT)
dic
# Out:
# {'level': [1, 2, 3, 4, 5],
#  'page_num': [1, 1, 1, 1, 1],
#  'block_num': [0, 1, 1, 1, 1],
#  'par_num': [0, 0, 1, 1, 1],
#  'line_num': [0, 0, 0, 1, 1],
#  'word_num': [0, 0, 0, 0, 1],
#  'left': [0, 43, 43, 43, 43],
#  'top': [0, 75, 75, 75, 75],
#  'width': [291, 210, 210, 210, 210],
#  'height': [173, 32, 32, 32, 32],
#  'conf': [-1, -1, -1, -1, 91],
#  'text': ['', '', '', '', 'MoonShine']}

# %%
x,y,w,h=43,75,210,32
cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255,3))
# Out:
# array([[[ 6,  5,  1],
#         [ 6,  5,  1],
#         [ 6,  5,  1],
#         ...,
#         [ 9,  4,  1],
#         [ 9,  4,  1],
#         [ 9,  4,  1]],
#
#        [[ 6,  5,  1],
#         [ 6,  5,  1],
#         [ 6,  5,  1],
#         ...,
#         [ 9,  4,  1],
#         [ 9,  4,  1],
#         [ 9,  4,  1]],
#
#        [[ 6,  5,  1],
#         [ 6,  5,  1],
#         [ 6,  5,  1],
#         ...,
#         [ 9,  4,  1],
#         [ 9,  4,  1],
#         [ 9,  4,  1]],
#
#        ...,
#
#        [[ 8,  3,  0],
#         [ 8,  3,  0],
#         [ 9,  4,  1],
#         ...,
#         [12,  7,  4],
#         [12,  7,  4],
#         [12,  7,  4]],
#
#        [[ 8,  3,  0],
#         [ 8,  3,  0],
#         [ 9,  4,  1],
#         ...,
#         [12,  7,  4],
#         [12,  7,  4],
#         [12,  7,  4]],
#
#        [[ 8,  3,  0],
#         [ 8,  3,  0],
#         [ 9,  4,  1],
#         ...,
#         [12,  7,  4],
#         [12,  7,  4],
# ...

# %%
cv2.imshow("frame",img)
cv2.waitKey(10000)
cv2.destroyAllWindows()
