# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlt
import seaborn as sns
import tensorflow as tf
df=pd.read_csv('Healthcare.csv')
df
# Out:
#        Patient_ID  Age  Gender  \
# 0               1   29    Male
# 1               2   76  Female
# 2               3   78    Male
# 3               4   58   Other
# 4               5   55  Female
# ...           ...  ...     ...
# 24995       24996   42    Male
# 24996       24997   36    Male
# 24997       24998   70   Other
# 24998       24999    9   Other
# 24999       25000   27  Female
#
#                                                 Symptoms  Symptom_Count  \
# 0                  fever, back pain, shortness of breath              3
# 1                       insomnia, back pain, weight loss              3
# 2                        sore throat, vomiting, diarrhea              3
# 3      blurred vision, depression, weight loss, muscl...              4
# 4                        swelling, appetite loss, nausea              3
# ...                                                  ...            ...
# 24995  runny nose, muscle pain, anxiety, depression, ...              6
# 24996  fever, blurred vision, insomnia, diarrhea, dep...              6
# 24997                           anxiety, nausea, tremors              3
# 24998            muscle pain, rash, diarrhea, joint pain              4
# 24999  sweating, abdominal pain, fever, insomnia, blu...              7
#
#                 Disease
# 0               Allergy
# 1      Thyroid Disorder
# 2             Influenza
# 3                Stroke
# 4         Heart Disease
# ...                 ...
# 24995             Ulcer
# 24996       Common Cold
# 24997           Anxiety
# 24998           Obesity
# 24999       Parkinson's
#
# [25000 rows x 6 columns]

# %%
df['Symptoms'].value_counts()
# Out:
# Symptoms
# sweating, abdominal pain, shortness of breath                  4
# appetite loss, weight loss, depression                         4
# chest pain, back pain, nausea                                  4
# tremors, nausea, insomnia                                      3
# cough, vomiting, nausea                                        3
#                                                               ..
# insomnia, back pain, fatigue                                   1
# fatigue, chest pain, muscle pain, nausea, runny nose           1
# abdominal pain, fatigue, tremors, depression                   1
# headache, rash, swelling, nausea                               1
# vomiting, appetite loss, anxiety, blurred vision, back pain    1
# Name: count, Length: 24359, dtype: int64
